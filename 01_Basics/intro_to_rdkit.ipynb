# %% [markdown]
# # Introduction to RDKit
# This notebook demonstrates the basics of molecule handling.

# %%
from rdkit import Chem
from rdkit.Chem import Draw

# Create Phenol molecule
mol = Chem.MolFromSmiles('c1ccccc1O')
mol
